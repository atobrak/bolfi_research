# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load the data files
X1_events_200_SH_SHSv = np.load('/home/kwabeato/Desktop/paper_plots/paper_images/events_200/X1_1.npy')
X3_events_200_Sv_SHSv = np.load('/home/kwabeato/Desktop/paper_plots/paper_images/events_200/X3_1.npy')
z_events_200_SHSv = np.load('/home/kwabeato/Desktop/paper_plots/paper_images/events_200/z_1.npy')


X1_events_200_Ovp_OvpSh = np.load('/home/kwabeato/Desktop/paper_plots/paper_images/events_200/X0_2.npy')
X3_events_200_Sh_OvpSh = np.load('/home/kwabeato/Desktop/paper_plots/paper_images/events_200/X2_2.npy')
z_events_200_OvpSh = np.load('/home/kwabeato/Desktop/paper_plots/paper_images/events_200/z_2.npy')


X1_events_200_Ovp_OvpSv = np.load('/home/kwabeato/Desktop/paper_plots/paper_images/events_200/X0_3.npy')
X3_events_200_Sv_OvpSv = np.load('/home/kwabeato/Desktop/paper_plots/paper_images/events_200/X3_3.npy')
z_events_200_OvpSv = np.load('/home/kwabeato/Desktop/paper_plots/paper_images/events_200/z_3.npy')


X1_events_200_Ovp_OvpSH = np.load('/home/kwabeato/Desktop/paper_plots/paper_images/events_200/X0_4.npy')
X3_events_200_SH_OvpSH = np.load('/home/kwabeato/Desktop/paper_plots/paper_images/events_200/X1_4.npy')
z_events_200_OvpSH = np.load('/home/kwabeato/Desktop/paper_plots/paper_images/events_200/z_4.npy')



X1_events_200_SH_SHSh = np.load('/home/kwabeato/Desktop/paper_plots/paper_images/events_200/X1_5.npy')
X3_events_200_Sh_SHSh = np.load('/home/kwabeato/Desktop/paper_plots/paper_images/events_200/X2_5.npy')
z_events_200_SHSh = np.load('/home/kwabeato/Desktop/paper_plots/paper_images/events_200/z_5.npy')


X1_events_200_Sh_ShSv = np.load('/home/kwabeato/Desktop/paper_plots/paper_images/events_200/X2_6.npy')
X3_events_200_Sv_ShSv = np.load('/home/kwabeato/Desktop/paper_plots/paper_images/events_200/X3_6.npy')
z_events_200_ShSv = np.load('/home/kwabeato/Desktop/paper_plots/paper_images/events_200/z_6.npy')

#=======================================================================================================#

X1_events_500_SH_SHSv = np.load('/home/kwabeato/Desktop/paper_plots/paper_images/events_500/X1_1.npy')
X3_events_500_Sv_SHSv = np.load('/home/kwabeato/Desktop/paper_plots/paper_images/events_500/X3_1.npy')
z_events_500_SHSv = np.load('/home/kwabeato/Desktop/paper_plots/paper_images/events_500/z_1.npy')


X1_events_500_Ovp_OvpSh = np.load('/home/kwabeato/Desktop/paper_plots/paper_images/events_500/X0_2.npy')
X3_events_500_Sh_OvpSh = np.load('/home/kwabeato/Desktop/paper_plots/paper_images/events_500/X2_2.npy')
z_events_500_OvpSh = np.load('/home/kwabeato/Desktop/paper_plots/paper_images/events_500/z_2.npy')

X1_events_500_Ovp_OvpSv = np.load('/home/kwabeato/Desktop/paper_plots/paper_images/events_500/X0_3.npy')
X3_events_500_Sv_OvpSv = np.load('/home/kwabeato/Desktop/paper_plots/paper_images/events_500/X3_3.npy')
z_events_500_OvpSv = np.load('/home/kwabeato/Desktop/paper_plots/paper_images/events_500/z_3.npy')


X1_events_500_Ovp_OvpSH = np.load('/home/kwabeato/Desktop/paper_plots/paper_images/events_500/X0_4.npy')
X3_events_500_SH_OvpSH = np.load('/home/kwabeato/Desktop/paper_plots/paper_images/events_500/X1_4.npy')
z_events_500_OvpSH = np.load('/home/kwabeato/Desktop/paper_plots/paper_images/events_500/z_4.npy')

X1_events_500_SH_SHSh = np.load('/home/kwabeato/Desktop/paper_plots/paper_images/events_500/X1_5.npy')
X3_events_500_Sh_SHSh = np.load('/home/kwabeato/Desktop/paper_plots/paper_images/events_500/X2_5.npy')
z_events_500_SHSh = np.load('/home/kwabeato/Desktop/paper_plots/paper_images/events_500/z_5.npy')

X1_events_500_Sh_ShSv = np.load('/home/kwabeato/Desktop/paper_plots/paper_images/events_500/X2_6.npy')
X3_events_500_Sv_ShSv = np.load('/home/kwabeato/Desktop/paper_plots/paper_images/events_500/X3_6.npy')
z_events_500_ShSv = np.load('/home/kwabeato/Desktop/paper_plots/paper_images/events_500/z_6.npy')

# %%
#loading npz files

data_events_200 = np.load('/home/kwabeato/Desktop/paper_plots/paper_images/events_200/data_save_final.npz')
data_events_500 = np.load('/home/kwabeato/Desktop/paper_plots/paper_images/events_500/data_save_final.npz')

# %%
#print("Arrays in the NPZ file:", data_events_200.files)

# %%
# Create figure with 6 subplots
plt.figure(figsize=(7, 5))

# Subplot 1
plt.subplot(2, 3, 1)
contour = plt.contour(X1_events_200_SH_SHSv, X3_events_200_Sv_SHSv, z_events_200_SHSv, levels=20, cmap='Blues')
plt.contourf(X1_events_200_SH_SHSv, X3_events_200_Sv_SHSv, z_events_200_SHSv, levels=20, cmap='Blues', alpha=0.7)
plt.clabel(contour, inline=True, fontsize=8)
plt.scatter( data_events_200['X'][:,1], data_events_200['X'][:,3], s=20, c='red', edgecolors='white', linewidth=0.5)
#plt.colorbar(label='z values')
plt.xlabel(r'$\sigma_H$', fontsize=14)
plt.ylabel(r'$\sigma_v$', fontsize=14)
plt.xticks([200, 270, 340])
plt.yticks([140, 190,  240])
plt.tick_params(axis='both', which='major', labelsize=12)
#plt.title('Contour Plot 1')
#plt.grid(True, alpha=0.3)

# Subplot 2
plt.subplot(2, 3, 2)
contour = plt.contour(X1_events_200_Ovp_OvpSh, X3_events_200_Sh_OvpSh, z_events_200_OvpSh, levels=20, cmap='Blues')
plt.contourf(X1_events_200_Ovp_OvpSh, X3_events_200_Sh_OvpSh, z_events_200_OvpSh, levels=20, cmap='Blues', alpha=0.7)
plt.clabel(contour, inline=True, fontsize=8)
#plt.colorbar(label='z values')
plt.scatter( data_events_200['X'][:,0], data_events_200['X'][:,2], s=20, c='red', edgecolors='white', linewidth=0.5)
plt.xlabel(r'$\sigma_p$', fontsize=14)
plt.ylabel(r'$\sigma_h$', fontsize=14)
plt.xticks([60, 100, 140])
plt.yticks([60, 100, 140])
plt.tick_params(axis='both', which='major', labelsize=12)
#plt.title('Contour Plot 2')
#plt.grid(True, alpha=0.3)

# Subplot 3
plt.subplot(2, 3, 3)
contour = plt.contour(X1_events_200_Ovp_OvpSv, X3_events_200_Sv_OvpSv, z_events_200_OvpSv, levels=20, cmap='Blues')
plt.contourf(X1_events_200_Ovp_OvpSv, X3_events_200_Sv_OvpSv, z_events_200_OvpSv, levels=20, cmap='Blues', alpha=0.7)
plt.clabel(contour, inline=True, fontsize=8)
#plt.colorbar(label='z values')
plt.scatter( data_events_200['X'][:,0], data_events_200['X'][:,3], s=20, c='red', edgecolors='white', linewidth=0.5)
plt.xlabel(r'$\sigma_p$', fontsize=14)
plt.ylabel(r'$\sigma_v$', fontsize=14)
plt.xticks([60, 100, 140])
plt.yticks([140, 190, 240])
plt.tick_params(axis='both', which='major', labelsize=12)
#plt.title('Contour Plot 3')
#plt.grid(True, alpha=0.3)

# Subplot 4
plt.subplot(2, 3, 4)
contour = plt.contour(X1_events_200_Ovp_OvpSH, X3_events_200_SH_OvpSH, z_events_200_OvpSH , levels=20, cmap='Blues')
plt.contourf(X1_events_200_Ovp_OvpSH, X3_events_200_SH_OvpSH, z_events_200_OvpSH, levels=20, cmap='Blues', alpha=0.7)
plt.clabel(contour, inline=True, fontsize=8)
#plt.colorbar(label='z values')
plt.scatter( data_events_200['X'][:,0], data_events_200['X'][:,1], s=20, c='red', edgecolors='white', linewidth=0.5)
plt.xlabel(r'$\sigma_p$', fontsize=14)
plt.ylabel(r'$\sigma_H$', fontsize=14)
plt.xticks([60, 100, 140])
plt.yticks([200, 270, 340])
plt.tick_params(axis='both', which='major', labelsize=12)
#plt.title('Contour Plot 4')
#plt.grid(True, alpha=0.3)

# Subplot 5
plt.subplot(2, 3, 5)
contour = plt.contour(X1_events_200_SH_SHSh, X3_events_200_Sh_SHSh, z_events_200_SHSh, levels=20, cmap='Blues')
plt.contourf(X1_events_200_SH_SHSh, X3_events_200_Sh_SHSh, z_events_200_SHSh, levels=20, cmap='Blues', alpha=0.7)
plt.clabel(contour, inline=True, fontsize=8)
#plt.colorbar(label='z values')
plt.scatter( data_events_200['X'][:,1], data_events_200['X'][:,2], s=20, c='red', edgecolors='white', linewidth=0.5)
plt.xlabel(r'$\sigma_H$', fontsize=14)
plt.ylabel(r'$\sigma_h$', fontsize=14)
plt.xticks([200, 270, 340])
plt.yticks([60, 100, 140])
plt.tick_params(axis='both', which='major', labelsize=12)
#plt.title('Contour Plot 5')
#plt.grid(True, alpha=0.3)

# Subplot 6
plt.subplot(2, 3, 6)
contour = plt.contour(X1_events_200_Sh_ShSv, X3_events_200_Sv_ShSv, z_events_200_ShSv, levels=20, cmap='Blues')
plt.contourf(X1_events_200_Sh_ShSv, X3_events_200_Sv_ShSv, z_events_200_ShSv, levels=20, cmap='Blues', alpha=0.7)
plt.clabel(contour, inline=True, fontsize=8)
#plt.colorbar(label='z values')
plt.scatter( data_events_200['X'][:,2], data_events_200['X'][:,3], s=20, c='red', edgecolors='white', linewidth=0.5)
plt.xlabel(r'$\sigma_h$', fontsize=14)
plt.ylabel(r'$\sigma_v$', fontsize=14)
plt.xticks([60, 100, 140])
plt.yticks([140, 190, 240])
plt.tick_params(axis='both', which='major', labelsize=12)
#plt.title('Contour Plot 6')
#plt.grid(True, alpha=0.3)

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Create figure with 6 subplots
plt.figure(figsize=(7, 5))

# Subplot 1
plt.subplot(2, 3, 1)
contour = plt.contour(X1_events_500_SH_SHSv, X3_events_500_Sv_SHSv, z_events_500_SHSv, levels=20, cmap='Blues')
plt.contourf(X1_events_500_SH_SHSv, X3_events_500_Sv_SHSv, z_events_500_SHSv, levels=20, cmap='Blues', alpha=0.7)
plt.clabel(contour, inline=True, fontsize=8)
plt.scatter( data_events_500['X'][:,1], data_events_500['X'][:,3], s=20, c='red', edgecolors='white', linewidth=0.5)
#plt.colorbar(label='z values')
plt.xlabel(r'$\sigma_H$', fontsize=14)
plt.ylabel(r'$\sigma_v$', fontsize=14)
plt.xticks([200, 270, 340])
plt.yticks([140, 190,  240])
plt.tick_params(axis='both', which='major', labelsize=12)
#plt.title('Contour Plot 1')
#plt.grid(True, alpha=0.3)

# Subplot 2
plt.subplot(2, 3, 2)
contour = plt.contour(X1_events_500_Ovp_OvpSh, X3_events_500_Sh_OvpSh, z_events_500_OvpSh, levels=20, cmap='Blues')
plt.contourf(X1_events_500_Ovp_OvpSh, X3_events_500_Sh_OvpSh, z_events_500_OvpSh, levels=20, cmap='Blues', alpha=0.7)
plt.clabel(contour, inline=True, fontsize=8)
#plt.colorbar(label='z values')
plt.scatter( data_events_500['X'][:,0], data_events_500['X'][:,2], s=20, c='red', edgecolors='white', linewidth=0.5)
plt.xlabel(r'$\sigma_p$', fontsize=14)
plt.ylabel(r'$\sigma_h$', fontsize=14)
plt.xticks([60, 100, 140])
plt.yticks([60, 100, 140])
plt.tick_params(axis='both', which='major', labelsize=12)
#plt.title('Contour Plot 2')
#plt.grid(True, alpha=0.3)

# Subplot 3
plt.subplot(2, 3, 3)
contour = plt.contour(X1_events_500_Ovp_OvpSv, X3_events_500_Sv_OvpSv, z_events_500_OvpSv, levels=20, cmap='Blues')
plt.contourf(X1_events_500_Ovp_OvpSv, X3_events_500_Sv_OvpSv, z_events_500_OvpSv, levels=20, cmap='Blues', alpha=0.7)
plt.clabel(contour, inline=True, fontsize=8)
#plt.colorbar(label='z values')
plt.scatter( data_events_500['X'][:,0], data_events_500['X'][:,3], s=20, c='red', edgecolors='white', linewidth=0.5)
plt.xlabel(r'$\sigma_p$', fontsize=14)
plt.ylabel(r'$\sigma_v$', fontsize=14)
plt.xticks([60, 100, 140])
plt.yticks([140, 190, 240])
plt.tick_params(axis='both', which='major', labelsize=12)
#plt.title('Contour Plot 3')
#plt.grid(True, alpha=0.3)

# Subplot 4
plt.subplot(2, 3, 4)
contour = plt.contour(X1_events_500_Ovp_OvpSH, X3_events_500_SH_OvpSH, z_events_500_OvpSH , levels=20, cmap='Blues')
plt.contourf(X1_events_500_Ovp_OvpSH, X3_events_500_SH_OvpSH, z_events_500_OvpSH, levels=20, cmap='Blues', alpha=0.7)
plt.clabel(contour, inline=True, fontsize=8)
#plt.colorbar(label='z values')
plt.scatter( data_events_500['X'][:,0], data_events_500['X'][:,1], s=20, c='red', edgecolors='white', linewidth=0.5)
plt.xlabel(r'$\sigma_p$', fontsize=14)
plt.ylabel(r'$\sigma_H$', fontsize=14)
plt.xticks([60, 100, 140])
plt.yticks([200, 270, 340])
plt.tick_params(axis='both', which='major', labelsize=12)
#plt.title('Contour Plot 4')
#plt.grid(True, alpha=0.3)

# Subplot 5
plt.subplot(2, 3, 5)
contour = plt.contour(X1_events_500_SH_SHSh, X3_events_500_Sh_SHSh, z_events_500_SHSh, levels=20, cmap='Blues')
plt.contourf(X1_events_500_SH_SHSh, X3_events_500_Sh_SHSh, z_events_500_SHSh, levels=20, cmap='Blues', alpha=0.7)
plt.clabel(contour, inline=True, fontsize=8)
#plt.colorbar(label='z values')
plt.scatter( data_events_500['X'][:,1], data_events_500['X'][:,2], s=20, c='red', edgecolors='white', linewidth=0.5)
plt.xlabel(r'$\sigma_H$', fontsize=14)
plt.ylabel(r'$\sigma_h$', fontsize=14)
plt.xticks([200, 270, 340])
plt.yticks([60, 100, 140])
plt.tick_params(axis='both', which='major', labelsize=12)
#plt.title('Contour Plot 5')
#plt.grid(True, alpha=0.3)

# Subplot 6
plt.subplot(2, 3, 6)
contour = plt.contour(X1_events_500_Sh_ShSv, X3_events_500_Sv_ShSv, z_events_500_ShSv, levels=20, cmap='Blues')
plt.contourf(X1_events_500_Sh_ShSv, X3_events_500_Sv_ShSv, z_events_500_ShSv, levels=20, cmap='Blues', alpha=0.7)
plt.clabel(contour, inline=True, fontsize=8)
#plt.colorbar(label='z values')
plt.scatter( data_events_500['X'][:,2], data_events_500['X'][:,3], s=20, c='red', edgecolors='white', linewidth=0.5)
plt.xlabel(r'$\sigma_h$', fontsize=14)
plt.ylabel(r'$\sigma_v$', fontsize=14)
plt.xticks([60, 100, 140])
plt.yticks([140, 190, 240])
plt.tick_params(axis='both', which='major', labelsize=12)
#plt.title('Contour Plot 6')
#plt.grid(True, alpha=0.3)

# Show the plot
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(7, 5))

contour = plt.contour(X1_events_500_SH_SHSv, X3_events_500_Sv_SHSv, z_events_500_SHSv, levels=20, cmap='Blues')
plt.contourf(X1_events_500_SH_SHSv, X3_events_500_Sv_SHSv, z_events_500_SHSv, levels=20, cmap='Blues', alpha=0.7)
plt.clabel(contour, inline=True, fontsize=8)
#plt.scatter( data_events_500['X'][:,1], data_events_500['X'][:,3], s=20, c='red', edgecolors='white', linewidth=0.5)
cbar = plt.colorbar(label='Discrepancy [-]')
cbar.set_ticks([3.6, 5, 6.4])  # set as you need based on your data range
plt.xlabel(r'$\sigma_H$', fontsize=14)
plt.ylabel(r'$\sigma_v$', fontsize=14)
plt.xticks([200, 270, 340])
plt.yticks([140, 190,  240])
plt.tick_params(axis='both', which='major', labelsize=12)
